# %% [markdown]
# <a href="https://colab.research.google.com/github/goktuggokmen/Multi-Temporal-Remote-Sensing-Image-Registration-Using-Deep-Convolutional-Features/blob/main/Image_Super_Resolution_(ISR).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ISR

# %%
# %%shell
# git clone https://github.com/idealo/image-super-resolution
# cd image-super-resolution
# python setup.py install
# Out:
# fatal: destination path 'image-super-resolution' already exists and is not an empty directory.
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# writing ISR.egg-info/PKG-INFO
# writing dependency_links to ISR.egg-info/dependency_links.txt
# writing requirements to ISR.egg-info/requires.txt
# writing top-level names to ISR.egg-info/top_level.txt
# adding license file 'LICENSE'
# writing manifest file 'ISR.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/ISR
# copying build/lib/ISR/__init__.py -> build/bdist.linux-x86_64/egg/ISR
# creating build/bdist.linux-x86_64/egg/ISR/predict
# ...

# %%
import numpy as np
from PIL import Image

img = Image.open('/content/drive/MyDrive/fish_18/fish_000027080001_02813.png')
lr_img = np.array(img)

# %%
# !pip uninstall h5py
# !pip install h5py==2.10.0
# Out:
# Found existing installation: h5py 2.10.0
# Uninstalling h5py-2.10.0:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/h5py-2.10.0-py3.7-linux-x86_64.egg
# Proceed (y/n)? y
#   Successfully uninstalled h5py-2.10.0
# ...
#      |████████████████████████████████| 2.9 MB 25.6 MB/s
# ...

# %%
Image.fromarray(lr_img)
# Out:
# <PIL.Image.Image image mode=RGB size=84x81 at 0x7F5C4E08F850>

# %%
# importing the module
import cv2

# loading the image

# fetching the dimensions
wid = lr_img.shape[1]
hgt = lr_img.shape[0]

# displaying the dimensions
print(str(wid) + "x" + str(hgt))
# Out:
# 84x81

# %%
from ISR.models import RDN

rdn = RDN(weights='psnr-small')
sr_img = rdn.predict(lr_img)
Image.fromarray(sr_img)
# Out:
# <PIL.Image.Image image mode=RGB size=168x162 at 0x7F5C4806FC90>

# %%
# loading the image

# fetching the dimensions
wid = sr_img.shape[1]
hgt = sr_img.shape[0]

# displaying the dimensions
print(str(wid) + "x" + str(hgt))
# Out:
# 168x162
